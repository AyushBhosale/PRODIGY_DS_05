# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("/kaggle/input/us-accidents/US_Accidents_March23.csv")
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
x=df.groupby('Wind_Direction').size().reset_index(name="counts")

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %%
df['Wind_Direction'].unique()
# Out:
# array(['Calm', 'SW', 'SSW', 'WSW', 'WNW', 'NW', 'West', 'NNW', 'NNE',
#        'South', 'North', 'Variable', 'SE', 'SSE', 'ESE', 'East', 'NE',
#        'ENE', 'E', 'W', nan, 'S', 'VAR', 'CALM', 'N'], dtype=object)

# %%
x=df.groupby('Wind_Direction').size().reset_index(name="counts")

# %%
px.bar(data_frame=x, x=x['Wind_Direction'].unique(),y='counts',barmode="group")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
df['Start_Time']=df['Start_Time'].replace(to_replace='\.\d+',value='',regex=True,)
df['End_Time']=df['End_Time'].replace(to_replace='\.\d+',value='',regex=True,)

# %%
#accidents on time
df['Start_Time']=pd.to_datetime(df['Start_Time'])
df['End_Time']=pd.to_datetime(df['End_Time'])

# %%
df1=df.groupby(['Country'])
df['Country'].unique()
# Out:
# array(['US'], dtype=object)

# %%
accidents_by_cities = df['City'].value_counts()
accidents_by_cities[:10]
# Out:
# City
# Miami          186917
# Houston        169609
# Los Angeles    156491
# Charlotte      138652
# Dallas         130939
# Orlando        109733
# Austin          97359
# Raleigh         86079
# Nashville       72930
# Baton Rouge     71588
# Name: count, dtype: int64

# %%
index=accidents_by_cities[:10].index
values=accidents_by_cities[:10].values

# %%
fig, ax = plt.subplots()
ax.bar(index,values)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=index,y=values)
# Out:
# <Axes: xlabel='City'>

# %%
accidents_severity = df.groupby('Severity').count()['ID']
accidents_severity
# Out:
# Severity
# 1      67366
# 2    6156981
# 3    1299337
# 4     204710
# Name: ID, dtype: int64

# %%
plt.pie(accidents_severity,labels=accidents_severity.index)
plt.show()

# %%
df['City'].value_counts().sort_values(ascending=False).head(20).keys()
# Out:
# Index(['Miami', 'Houston', 'Los Angeles', 'Charlotte', 'Dallas', 'Orlando',
#        'Austin', 'Raleigh', 'Nashville', 'Baton Rouge', 'Atlanta',
#        'Sacramento', 'San Diego', 'Phoenix', 'Minneapolis', 'Richmond',
#        'Oklahoma City', 'Jacksonville', 'Tucson', 'Columbia'],
#       dtype='object', name='City')

# %%
df['City'].value_counts().sort_values(ascending=False).head(20).index
# Out:
# Index(['Miami', 'Houston', 'Los Angeles', 'Charlotte', 'Dallas', 'Orlando',
#        'Austin', 'Raleigh', 'Nashville', 'Baton Rouge', 'Atlanta',
#        'Sacramento', 'San Diego', 'Phoenix', 'Minneapolis', 'Richmond',
#        'Oklahoma City', 'Jacksonville', 'Tucson', 'Columbia'],
#       dtype='object', name='City')

# %%
# Let's see it on graph
top_20 = df['City'].value_counts().sort_values(ascending=False).head(20)
sns.barplot(y=top_20.keys(),x=top_20.values)
plt.tight_layout()

# %%
start_hour=df['Start_Time'].dt.hour
end_hour=df['End_Time'].dt.hour
# Out:
# 0           5
# 1           6
# 2           6
# 3           7
# 4           7
#            ..
# 7728389    18
# 7728390    19
# 7728391    19
# 7728392    19
# 7728393    18
# Name: Start_Time, Length: 7728394, dtype: int32

# %%
sns.histplot(start_hour, color='blue', bins=24, stat='percent')

# %%
sns.histplot(end_hour, color='red',bins=24, stat='percent')
# Out:
# <Axes: xlabel='End_Time', ylabel='Percent'>

# %%
for i in range(7):
    sns.histplot(df['Start_Time'][df['Start_Time'].dt.dayofweek==i].dt.hour,bins=24)
    plt.title(i)
    plt.show()

# %%
sns.histplot(df['Start_Time'].dt.month,bins=12,color='red')
plt.show()

# %%
for i in range(7):
    day_time=df['Start_Time'][df['Start_Time'].dt.dayofweek==i]
    sns.histplot(day_time.dt.month,bins=12,color='red')
    plt.title(i)
    plt.show()
